# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# Out:
# Requirement already satisfied: matplotlib in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (3.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: numpy>=1.16 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.20.3)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %matplotlib inline

for ticker in tickers:
    # read in data from csv
    data = pd.read_csv(f'./data/{ticker}.csv')

    # generate matrix with technical indicators (features) as columns
    features = data.to_numpy()[:, 6:]

    # normalize each feature
    scaler = StandardScaler()
    X = scaler.fit_transform(features)
    
    
    
    
    # project the data along the first 2 principal components
    pca = PCA(n_components=2)
    X_proj = pca.fit_transform(X)

    # plot the transformed data
    fig = plt.figure()
    ax = plt.axes()
    ax.scatter(X_proj[:, 0], X_proj[:, 1],s=1)
    ax.set_xlabel("1st Component")
    ax.set_ylabel("2nd Component")
    plt.title(ticker)

    fig.set_size_inches(6, 6)
    if not os.path.exists("figs"):
            os.mkdir("figs")
    plt.savefig('./figs/' + ticker + '_2d_pca.png', dpi=200)
    
    
    

    # project the data along the first 3 principal components
    pca = PCA(n_components=3)
    X_proj = pca.fit_transform(X)

    # plot the transformed data
    fig = plt.figure()
    ax = plt.axes(projection="3d")
    ax.scatter3D(X_proj[:, 0], X_proj[:, 1], X_proj[:, 2],s=1)
    ax.set_xlabel("1st Component")
    ax.set_ylabel("2nd Component")
    ax.set_zlabel("3rd Component")
    plt.title(ticker)

    fig.set_size_inches(6, 6)
    if not os.path.exists("figs"):
            os.mkdir("figs")
    plt.savefig('./figs/' + ticker + '_3d_pca.png', dpi=200)
# Out:
# /var/folders/1f/0j682mk93d35p42prjrn5whr0000gn/T/ipykernel_10364/2081363604.py:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

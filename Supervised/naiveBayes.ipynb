# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: sklearn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy>=1.14.6 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: joblib>=0.11 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: pandas in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, ComplementNB, MultinomialNB
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix

for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)
    
    model = GaussianNB()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    # this confusion matrix sucks, even on own training data
    
    plot_confusion_matrix(model, X_test, y_test)
    plt.title(f'Confusion matrix for {ticker}')
    plt.show()
    
    print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.47      0.99      0.63       218
#          1.0       0.00      0.00      0.00        52
#          2.0       0.13      0.02      0.04        99
#          3.0       0.00      0.00      0.00       106
#
#     accuracy                           0.46       475
#    macro avg       0.15      0.25      0.17       475
# weighted avg       0.24      0.46      0.30       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.94      0.59       202
#          1.0       0.00      0.00      0.00        82
#          2.0       0.00      0.00      0.00        76
#          3.0       0.16      0.05      0.08       115
#
#     accuracy                           0.41       475
#    macro avg       0.15      0.25      0.17       475
# weighted avg       0.22      0.41      0.27       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.93      0.55       125
#          1.0       0.00      0.00      0.00        80
#          2.0       0.17      0.03      0.05        66
#          3.0       0.26      0.10      0.14        62
#
#     accuracy                           0.37       333
#    macro avg       0.20      0.26      0.19       333
# weighted avg       0.23      0.37      0.24       333
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.57      0.45       110
#          1.0       0.00      0.00      0.00        92
#          2.0       0.43      0.76      0.55       173
#          3.0       0.00      0.00      0.00       100
#
#     accuracy                           0.41       475
#    macro avg       0.20      0.33      0.25       475
# weighted avg       0.24      0.41      0.30       475
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.75      0.44       146
#          1.0       0.00      0.00      0.00       115
#          2.0       0.31      0.29      0.30       135
#          3.0       0.00      0.00      0.00        79
#
#     accuracy                           0.31       475
#    macro avg       0.16      0.26      0.18       475
# weighted avg       0.18      0.31      0.22       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.63      0.49       176
#          1.0       0.00      0.00      0.00        83
#          2.0       0.31      0.48      0.38       126
#          3.0       0.00      0.00      0.00        90
#
#     accuracy                           0.36       475
#    macro avg       0.18      0.28      0.22       475
# weighted avg       0.23      0.36      0.28       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.51      0.46       130
#          1.0       0.38      0.48      0.42       123
#          2.0       0.38      0.51      0.44       124
#          3.0       0.00      0.00      0.00        98
#
#     accuracy                           0.40       475
#    macro avg       0.30      0.37      0.33       475
# weighted avg       0.31      0.40      0.35       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.57      0.51       147
#          1.0       0.00      0.00      0.00        86
#          2.0       0.39      0.72      0.51       159
#          3.0       0.00      0.00      0.00        83
#
#     accuracy                           0.42       475
#    macro avg       0.21      0.32      0.25       475
# weighted avg       0.27      0.42      0.33       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.50      0.39       103
#          1.0       0.00      0.00      0.00       107
#          2.0       0.39      0.72      0.51       168
#          3.0       0.00      0.00      0.00        97
#
#     accuracy                           0.36       475
#    macro avg       0.18      0.31      0.22       475
# weighted avg       0.21      0.36      0.26       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.98      0.54       125
#          1.0       1.00      0.01      0.03        78
#          2.0       0.48      0.13      0.21        75
#          3.0       0.00      0.00      0.00        71
#
#     accuracy                           0.38       349
#    macro avg       0.46      0.28      0.19       349
# weighted avg       0.46      0.38      0.25       349
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.87      0.55        52
#          1.0       0.53      0.24      0.33        34
#          2.0       0.00      0.00      0.00        19
#          3.0       0.17      0.06      0.09        34
#
#     accuracy                           0.40       139
#    macro avg       0.28      0.29      0.24       139
# weighted avg       0.32      0.40      0.31       139
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.43      0.39       153
#          1.0       0.26      0.09      0.14        87
#          2.0       0.29      0.45      0.35       137
#          3.0       0.20      0.09      0.12        98
#
#     accuracy                           0.30       475
#    macro avg       0.27      0.27      0.25       475
# weighted avg       0.28      0.30      0.28       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.03      0.05        69
#          1.0       0.50      0.38      0.43       136
#          2.0       0.33      0.77      0.46       155
#          3.0       0.00      0.00      0.00       115
#
#     accuracy                           0.36       475
#    macro avg       0.29      0.29      0.24       475
# weighted avg       0.30      0.36      0.28       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.92      0.59       197
#          1.0       0.00      0.00      0.00        90
#          2.0       0.33      0.16      0.22       106
#          3.0       0.33      0.01      0.02        82
#
#     accuracy                           0.42       475
#    macro avg       0.27      0.27      0.21       475
# weighted avg       0.31      0.42      0.30       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.27      0.33      0.30       106
#          1.0       0.00      0.00      0.00        82
#          2.0       0.39      0.72      0.51       188
#          3.0       0.00      0.00      0.00        99
#
#     accuracy                           0.36       475
#    macro avg       0.17      0.26      0.20       475
# weighted avg       0.22      0.36      0.27       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.47      0.54        55
#          1.0       0.33      0.81      0.47        37
#          2.0       0.00      0.00      0.00        21
#          3.0       0.00      0.00      0.00        19
#
#     accuracy                           0.42       132
#    macro avg       0.24      0.32      0.25       132
# weighted avg       0.36      0.42      0.36       132
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.60      0.49        77
#          1.0       0.39      0.79      0.52       158
#          2.0       0.24      0.08      0.11       133
#          3.0       0.00      0.00      0.00       107
#
#     accuracy                           0.38       475
#    macro avg       0.26      0.37      0.28       475
# weighted avg       0.26      0.38      0.28       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.93      0.58       196
#          1.0       0.00      0.00      0.00        85
#          2.0       0.16      0.07      0.10       100
#          3.0       0.00      0.00      0.00        94
#
#     accuracy                           0.40       475
#    macro avg       0.14      0.25      0.17       475
# weighted avg       0.21      0.40      0.26       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.24      0.19      0.21       116
#          1.0       0.32      0.79      0.45       136
#          2.0       0.00      0.00      0.00       104
#          3.0       0.35      0.14      0.20       119
#
#     accuracy                           0.31       475
#    macro avg       0.23      0.28      0.22       475
# weighted avg       0.24      0.31      0.23       475
# /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.93      0.56       189
#          1.0       0.29      0.05      0.09        99
#          2.0       0.30      0.06      0.10       104
#          3.0       0.00      0.00      0.00        83
#
#     accuracy                           0.39       475
#    macro avg       0.25      0.26      0.19       475
# weighted avg       0.29      0.39      0.26       475

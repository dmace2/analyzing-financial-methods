# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (3.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (1.21.4)
# Requirement already satisfied: pandas in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix
from sklearn.neighbors import (NeighborhoodComponentsAnalysis, KNeighborsClassifier)
from sklearn.pipeline import Pipeline

for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)
    
    # build and fit a KNeighbors classifier on X_train and y_train
    nca = NeighborhoodComponentsAnalysis(random_state=42)
    knn = KNeighborsClassifier(n_neighbors=3)
    

    y_pred = knn.predict(X_test)
    
    plot_confusion_matrix(knn, X_test, y_test, normalize='pred')
    plt.title(f'Confusion matrix for {ticker}')
    plt.show()

    print(classification_report(y_test, y_pred))
    
    nca_pipe = Pipeline([('nca', nca), ('knn', knn)])
    nca_pipe.fit(X_train, y_train)
    print(nca_pipe.score(X_test, y_test))
# Out:
# 0.36
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.42      0.72      0.53       194
#          1.0       0.08      0.03      0.04        65
#          2.0       0.26      0.20      0.22       111
#          3.0       0.25      0.08      0.12       105
#
#     accuracy                           0.36       475
#    macro avg       0.25      0.26      0.23       475
# weighted avg       0.30      0.36      0.30       475
#
# 0.3031578947368421
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.57      0.43       174
#          1.0       0.15      0.15      0.15        73
#          2.0       0.28      0.10      0.15       108
#          3.0       0.30      0.19      0.23       120
#
#     accuracy                           0.30       475
#    macro avg       0.27      0.25      0.24       475
# weighted avg       0.29      0.30      0.27       475
#
# 0.27844311377245506
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.32      0.56      0.41       107
#          1.0       0.19      0.20      0.20        64
#          2.0       0.23      0.09      0.13        75
#          3.0       0.28      0.15      0.19        88
#
#     accuracy                           0.28       334
#    macro avg       0.25      0.25      0.23       334
# weighted avg       0.26      0.28      0.25       334
#
# 0.3494736842105263
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.30      0.53      0.38       105
#          1.0       0.28      0.29      0.29        72
#          2.0       0.46      0.39      0.42       189
#          3.0       0.30      0.15      0.20       109
#
#     accuracy                           0.35       475
#    macro avg       0.33      0.34      0.32       475
# weighted avg       0.36      0.35      0.34       475
#
# 0.2968421052631579
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.58      0.45       157
#          1.0       0.29      0.25      0.27       108
#          2.0       0.28      0.22      0.25       119
#          3.0       0.20      0.09      0.12        91
#
#     accuracy                           0.32       475
#    macro avg       0.28      0.28      0.27       475
# weighted avg       0.29      0.32      0.29       475
#
# 0.35789473684210527
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.64      0.48       164
#          1.0       0.30      0.20      0.24        85
#          2.0       0.37      0.21      0.27       142
#          3.0       0.31      0.21      0.25        84
#
#     accuracy                           0.36       475
#    macro avg       0.34      0.32      0.31       475
# weighted avg       0.35      0.36      0.33       475
#
# 0.35578947368421054
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.52      0.41       121
#          1.0       0.36      0.40      0.38       116
#          2.0       0.40      0.32      0.35       126
#          3.0       0.33      0.18      0.23       112
#
#     accuracy                           0.36       475
#    macro avg       0.36      0.35      0.34       475
# weighted avg       0.36      0.36      0.34       475
#
# 0.3452631578947368
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.53      0.45       157
#          1.0       0.26      0.23      0.25        81
#          2.0       0.40      0.33      0.36       155
#          3.0       0.18      0.13      0.15        82
#
#     accuracy                           0.35       475
#    macro avg       0.31      0.31      0.30       475
# weighted avg       0.33      0.35      0.33       475
#
# 0.36210526315789476
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.33      0.55      0.41       112
#          1.0       0.24      0.26      0.25       103
#          2.0       0.50      0.40      0.44       167
#          3.0       0.39      0.18      0.25        93
#
#     accuracy                           0.36       475
#    macro avg       0.36      0.35      0.34       475
# weighted avg       0.38      0.36      0.36       475
#
# 0.29512893982808025
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.61      0.46       126
#          1.0       0.19      0.15      0.17        66
#          2.0       0.17      0.11      0.13        84
#          3.0       0.21      0.10      0.13        73
#
#     accuracy                           0.30       349
#    macro avg       0.23      0.24      0.22       349
# weighted avg       0.25      0.30      0.26       349
#
# 0.28776978417266186
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.41      0.35        51
#          1.0       0.30      0.26      0.28        34
#          2.0       0.12      0.04      0.06        23
#          3.0       0.27      0.29      0.28        31
#
#     accuracy                           0.29       139
#    macro avg       0.25      0.25      0.24       139
# weighted avg       0.27      0.29      0.27       139
#
# 0.2926315789473684
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.49      0.41       168
#          1.0       0.11      0.07      0.09        69
#          2.0       0.33      0.25      0.28       152
#          3.0       0.17      0.16      0.16        86
#
#     accuracy                           0.29       475
#    macro avg       0.24      0.24      0.24       475
# weighted avg       0.28      0.29      0.28       475
#
# 0.38526315789473686
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.37      0.46      0.41        85
#          1.0       0.40      0.52      0.46       126
#          2.0       0.39      0.33      0.35       162
#          3.0       0.36      0.25      0.29       102
#
#     accuracy                           0.39       475
#    macro avg       0.38      0.39      0.38       475
# weighted avg       0.38      0.39      0.38       475
#
# 0.33263157894736844
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.63      0.49       192
#          1.0       0.19      0.14      0.16        96
#          2.0       0.20      0.14      0.17        97
#          3.0       0.26      0.11      0.16        90
#
#     accuracy                           0.33       475
#    macro avg       0.26      0.26      0.24       475
# weighted avg       0.29      0.33      0.30       475
#
# 0.35789473684210527
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.48      0.41       131
#          1.0       0.27      0.26      0.27        80
#          2.0       0.46      0.41      0.43       180
#          3.0       0.22      0.15      0.18        84
#
#     accuracy                           0.36       475
#    macro avg       0.33      0.33      0.32       475
# weighted avg       0.36      0.36      0.35       475
#
# 0.4015151515151515
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.65      0.53        49
#          1.0       0.32      0.38      0.35        37
#          2.0       0.42      0.19      0.26        27
#          3.0       0.40      0.11      0.17        19
#
#     accuracy                           0.40       132
#    macro avg       0.40      0.33      0.33       132
# weighted avg       0.40      0.40      0.37       132
#
# 0.3705263157894737
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.48      0.36        65
#          1.0       0.45      0.50      0.47       170
#          2.0       0.37      0.23      0.28       133
#          3.0       0.31      0.28      0.29       107
#
#     accuracy                           0.37       475
#    macro avg       0.35      0.37      0.35       475
# weighted avg       0.37      0.37      0.36       475
#
# 0.3094736842105263
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.62      0.49       185
#          1.0       0.18      0.14      0.15       103
#          2.0       0.20      0.13      0.16       107
#          3.0       0.11      0.06      0.08        80
#
#     accuracy                           0.31       475
#    macro avg       0.22      0.24      0.22       475
# weighted avg       0.26      0.31      0.27       475
#
# 0.27578947368421053
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.27      0.44      0.33       126
#          1.0       0.30      0.29      0.30       135
#          2.0       0.27      0.17      0.20       102
#          3.0       0.26      0.18      0.21       112
#
#     accuracy                           0.28       475
#    macro avg       0.27      0.27      0.26       475
# weighted avg       0.28      0.28      0.27       475
#
# 0.32421052631578945
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\base.py:438: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.61      0.46       175
#          1.0       0.27      0.22      0.24       105
#          2.0       0.16      0.09      0.12        98
#          3.0       0.30      0.16      0.21        97
#
#     accuracy                           0.32       475
#    macro avg       0.28      0.27      0.26       475
# weighted avg       0.29      0.32      0.29       475

# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: cycler>=0.10 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: sklearn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: pandas in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

import pandas as pd

totalData = pd.DataFrame()


for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    totalData = totalData.append(data)
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)
    
    # build and fit a random forest classifier on X_train and y_train
    rf = RandomForestClassifier(n_estimators=100, random_state=None)
    rf.fit(X_train, y_train)

    feature_importances = [(features.columns.values[i], rf.feature_importances_[i]) for i in range(len(rf.feature_importances_))]




    print("Feature Importances: ", rf.feature_importances_)
    # evaluate accuract of random forest

    y_pred = rf.predict(X_test)

    ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, normalize='pred')

    plt.title(f'Confusion matrix for {ticker}')
    plt.show()
    print(classification_report(y_test, y_pred))

print(totalData.head())
features, labels = totalData.drop(['policy', 'Date'], axis=1), totalData['policy']
    
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)

# build and fit a random forest classifier on X_train and y_train
rf = RandomForestClassifier(n_estimators=100, random_state=None)
rf.fit(X_train, y_train)
# evaluate accuract of random forest

y_pred = rf.predict(X_test)

ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, normalize='pred')

plt.title(f'Confusion matrix for totalData')
plt.savefig('totalData_confusion_matrix.png')
plt.show()
print(classification_report(y_test, y_pred))
# Out:
# Feature Importances:  [0.05654052 0.04904965 0.05543984 0.06258555 0.09611158 0.0475566
#  0.05537668 0.09661959 0.16571928 0.04752218 0.06892706 0.0476352
#  0.05824717 0.09266911]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.93      0.87       216
#          1.0       0.85      0.49      0.62        45
#          2.0       0.76      0.68      0.72       121
#          3.0       0.73      0.77      0.75        93
#
#     accuracy                           0.79       475
#    macro avg       0.79      0.72      0.74       475
# weighted avg       0.79      0.79      0.79       475
#
# Feature Importances:  [0.05887866 0.05177781 0.05401192 0.07349654 0.09387414 0.04461854
#  0.05838384 0.08927071 0.15724262 0.04814672 0.07231653 0.04813836
#  0.05944769 0.09039592]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.87      0.86       193
#          1.0       0.81      0.70      0.75        77
#          2.0       0.61      0.60      0.60        87
#          3.0       0.70      0.74      0.72       118
#
#     accuracy                           0.76       475
#    macro avg       0.74      0.73      0.73       475
# weighted avg       0.76      0.76      0.76       475
#
# Feature Importances:  [0.05675438 0.04969707 0.05157025 0.06749099 0.09429145 0.04425803
#  0.05631342 0.09456859 0.15744284 0.04867426 0.08008311 0.04845224
#  0.05352231 0.09688106]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.87      0.86       129
#          1.0       0.85      0.91      0.88        67
#          2.0       0.65      0.64      0.65        64
#          3.0       0.81      0.74      0.77        73
#
#     accuracy                           0.80       333
#    macro avg       0.79      0.79      0.79       333
# weighted avg       0.80      0.80      0.80       333
#
# Feature Importances:  [0.05420778 0.0523101  0.04492033 0.08909549 0.13112624 0.03923639
#  0.04938509 0.08025247 0.13306532 0.06923942 0.06279141 0.03947367
#  0.05300885 0.10188743]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.79      0.77       117
#          1.0       0.82      0.87      0.84        67
#          2.0       0.82      0.83      0.82       181
#          3.0       0.85      0.75      0.80       110
#
#     accuracy                           0.81       475
#    macro avg       0.81      0.81      0.81       475
# weighted avg       0.81      0.81      0.81       475
#
# Feature Importances:  [0.05615563 0.06065603 0.05441238 0.07630688 0.11987441 0.04644333
#  0.05625096 0.08366128 0.11932636 0.05811592 0.06814912 0.04617877
#  0.06064602 0.09382291]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.87      0.87       169
#          1.0       0.80      0.87      0.83       109
#          2.0       0.71      0.73      0.72       116
#          3.0       0.71      0.58      0.64        81
#
#     accuracy                           0.79       475
#    macro avg       0.77      0.76      0.77       475
# weighted avg       0.79      0.79      0.78       475
#
# Feature Importances:  [0.05768723 0.05091911 0.04422568 0.08476322 0.12067567 0.03870698
#  0.05368711 0.08305949 0.12863602 0.06280139 0.06896886 0.04067663
#  0.06033617 0.10485644]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.85      0.86       172
#          1.0       0.84      0.84      0.84        81
#          2.0       0.76      0.84      0.80       141
#          3.0       0.76      0.65      0.70        81
#
#     accuracy                           0.81       475
#    macro avg       0.81      0.80      0.80       475
# weighted avg       0.81      0.81      0.81       475
#
# Feature Importances:  [0.04996389 0.04698026 0.04357556 0.10402007 0.14361468 0.0376898
#  0.0497949  0.07693328 0.12869566 0.07732952 0.06113731 0.03779294
#  0.05262964 0.08984251]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.83      0.83       123
#          1.0       0.85      0.90      0.88       115
#          2.0       0.79      0.80      0.80       124
#          3.0       0.83      0.76      0.79       113
#
#     accuracy                           0.82       475
#    macro avg       0.82      0.82      0.82       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [0.05067629 0.05548166 0.04427298 0.10457639 0.1181217  0.03716924
#  0.04791939 0.07994593 0.11899522 0.06003818 0.06993006 0.03998641
#  0.05346648 0.11942006]
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.83      0.83       151
#          1.0       0.80      0.88      0.84        89
#          2.0       0.74      0.83      0.78       145
#          3.0       0.79      0.59      0.68        90
#
#     accuracy                           0.79       475
#    macro avg       0.79      0.78      0.78       475
# weighted avg       0.79      0.79      0.79       475
#
# Feature Importances:  [0.05208243 0.0483865  0.04022277 0.09614156 0.14101918 0.03503333
#  0.04803329 0.09094679 0.15909349 0.06758629 0.05734417 0.03616125
#  0.04702362 0.08092532]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.72      0.78       130
#          1.0       0.88      0.97      0.92        94
#          2.0       0.77      0.88      0.82       169
#          3.0       0.86      0.77      0.81        82
#
#     accuracy                           0.83       475
#    macro avg       0.85      0.83      0.84       475
# weighted avg       0.84      0.83      0.83       475
#
# Feature Importances:  [0.05559761 0.04959759 0.05040145 0.06334953 0.10416096 0.04421219
#  0.05940898 0.09563281 0.1580069  0.0491428  0.07802165 0.0449308
#  0.05685544 0.0906813 ]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.95      0.85       115
#          1.0       0.79      0.78      0.78        67
#          2.0       0.80      0.55      0.65        92
#          3.0       0.63      0.67      0.65        75
#
#     accuracy                           0.75       349
#    macro avg       0.75      0.74      0.74       349
# weighted avg       0.75      0.75      0.74       349
#
# Feature Importances:  [0.05443855 0.05339284 0.05562981 0.08005164 0.06923698 0.04261554
#  0.04803245 0.10328501 0.15634112 0.04154796 0.07056903 0.0387218
#  0.06854644 0.11759083]
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.95      0.94        56
#          1.0       0.80      0.92      0.86        26
#          2.0       0.88      0.58      0.70        24
#          3.0       0.72      0.79      0.75        33
#
#     accuracy                           0.84       139
#    macro avg       0.83      0.81      0.81       139
# weighted avg       0.85      0.84      0.84       139
#
# Feature Importances:  [0.06047986 0.05563218 0.05344115 0.06362888 0.09436543 0.04643398
#  0.06001728 0.08262012 0.14913041 0.05300985 0.07773174 0.04828006
#  0.06539388 0.08983519]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.79      0.78       160
#          1.0       0.77      0.71      0.74        72
#          2.0       0.65      0.70      0.67       134
#          3.0       0.75      0.70      0.72       109
#
#     accuracy                           0.73       475
#    macro avg       0.74      0.72      0.73       475
# weighted avg       0.73      0.73      0.73       475
#
# Feature Importances:  [0.04885993 0.05939097 0.03791801 0.10037111 0.13137364 0.03267384
#  0.04857111 0.08187489 0.14456629 0.06641702 0.05973143 0.03924266
#  0.04972624 0.09928286]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.80      0.84        70
#          1.0       0.90      0.91      0.91       141
#          2.0       0.82      0.90      0.86       164
#          3.0       0.80      0.71      0.75       100
#
#     accuracy                           0.85       475
#    macro avg       0.85      0.83      0.84       475
# weighted avg       0.85      0.85      0.85       475
#
# Feature Importances:  [0.0614158  0.06687191 0.05575693 0.08374044 0.0833579  0.04209967
#  0.05650633 0.09147938 0.13508297 0.05317929 0.06756262 0.04448096
#  0.06363774 0.09482806]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.94      0.88       192
#          1.0       0.87      0.88      0.87        99
#          2.0       0.75      0.71      0.73        94
#          3.0       0.85      0.64      0.73        90
#
#     accuracy                           0.83       475
#    macro avg       0.83      0.79      0.80       475
# weighted avg       0.83      0.83      0.82       475
#
# Feature Importances:  [0.05385304 0.05859618 0.04556519 0.09690552 0.14113988 0.03584589
#  0.04621987 0.07876477 0.13803701 0.05849961 0.06597894 0.03855784
#  0.05401651 0.08801975]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.85      0.82       107
#          1.0       0.87      0.83      0.85        87
#          2.0       0.85      0.84      0.84       192
#          3.0       0.73      0.72      0.72        89
#
#     accuracy                           0.82       475
#    macro avg       0.81      0.81      0.81       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [0.06102375 0.04977346 0.04103987 0.06813418 0.11533101 0.03978569
#  0.04890086 0.13317003 0.15945958 0.04328893 0.05652784 0.03142256
#  0.05435054 0.0977917 ]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.95      0.93        43
#          1.0       0.88      0.90      0.89        40
#          2.0       0.88      0.84      0.86        25
#          3.0       0.82      0.75      0.78        24
#
#     accuracy                           0.88       132
#    macro avg       0.87      0.86      0.87       132
# weighted avg       0.88      0.88      0.88       132
#
# Feature Importances:  [0.04814032 0.06551098 0.0395463  0.09723575 0.1262872  0.02974059
#  0.04809365 0.08181623 0.1231515  0.0661875  0.06537745 0.03452444
#  0.05754998 0.11683811]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.79      0.79        66
#          1.0       0.81      0.91      0.86       135
#          2.0       0.84      0.79      0.81       136
#          3.0       0.82      0.78      0.80       138
#
#     accuracy                           0.82       475
#    macro avg       0.82      0.82      0.82       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [0.0552114  0.05187586 0.05043272 0.06854176 0.10685922 0.04329088
#  0.0534667  0.08704641 0.16355639 0.0475567  0.06947426 0.0433464
#  0.06000577 0.09933552]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.95      0.90       190
#          1.0       0.77      0.85      0.81        92
#          2.0       0.78      0.61      0.68       107
#          3.0       0.75      0.70      0.72        86
#
#     accuracy                           0.81       475
#    macro avg       0.79      0.78      0.78       475
# weighted avg       0.80      0.81      0.80       475
#
# Feature Importances:  [0.06037496 0.05720715 0.05386541 0.08452727 0.11927515 0.04539314
#  0.0592388  0.0835273  0.12271053 0.05102321 0.06449528 0.04726583
#  0.06037818 0.09071779]
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.81      0.80       116
#          1.0       0.72      0.84      0.77       128
#          2.0       0.67      0.61      0.64        99
#          3.0       0.77      0.67      0.71       132
#
#     accuracy                           0.74       475
#    macro avg       0.73      0.73      0.73       475
# weighted avg       0.74      0.74      0.73       475
#
# Feature Importances:  [0.06490456 0.05260476 0.04883236 0.06210973 0.09993141 0.04141906
#  0.05939846 0.0920404  0.14516396 0.04578491 0.06851399 0.04526634
#  0.06750114 0.10652893]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90       181
#          1.0       0.85      0.80      0.83       102
#          2.0       0.82      0.77      0.80       109
#          3.0       0.74      0.77      0.76        83
#
#     accuracy                           0.84       475
#    macro avg       0.83      0.82      0.82       475
# weighted avg       0.84      0.84      0.84       475
#
#          Date        RSI   Ultimate  BandRadius       Chaikin      NATR  \
# 0  2012-04-17  46.489795  40.172901    0.017539 -2.317608e+06  2.760208
# 1  2012-04-18  50.201195  42.226659    0.020880 -2.024667e+06  2.716261
# 2  2012-04-19  50.242796  44.081433    0.021734 -2.277916e+06  2.701259
# 3  2012-04-20  48.610047  43.478910    0.022113 -3.105531e+06  2.661459
# 4  2012-04-23  46.103428  41.853508    0.013225 -2.531597e+06  2.663815
#
#       SMA_5    SMA_20   SMA_100       SAR  Williams%R       APO     ROC_5  \
# 0  0.999002  1.033505  0.989558  0.886300  -79.700196  0.000487  0.007541
# 1  0.988235  1.018679  0.975612  0.873868  -68.017200 -0.006056  0.016492
# 2  0.988509  1.018354  0.975569  0.873731  -67.887895 -0.010396  0.002150
# 3  0.995936  1.023721  0.981720  0.878882  -66.221985 -0.016266  0.008065
# 4  1.008054  1.031377  0.990480  0.887006  -75.506882 -0.019740  0.014771
#
#      ROC_20   ROC_100  policy
# 0  0.015470 -0.004544     0.0
# 1 -0.006551 -0.006603     0.0
# 2 -0.003286  0.011165     0.0
# 3 -0.012578  0.041557     0.0
# 4 -0.034865 -0.030440     0.0
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.87      0.81      2680
#          1.0       0.83      0.79      0.81      1746
#          2.0       0.75      0.74      0.74      2318
#          3.0       0.75      0.63      0.69      1799
#
#     accuracy                           0.77      8543
#    macro avg       0.77      0.76      0.76      8543
# weighted avg       0.77      0.77      0.76      8543

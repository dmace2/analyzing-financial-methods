# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (3.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (4.28.1)
# Requirement already satisfied: cycler>=0.10 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: sklearn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: numpy in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: pandas in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.20.0 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: six>=1.5 in /Users/dylanmace/miniforge3/envs/ml_proj/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

import pandas as pd

totalData = pd.DataFrame()


for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    totalData = totalData.append(data)
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)
    
    # build and fit a random forest classifier on X_train and y_train
    rf = RandomForestClassifier(n_estimators=100, random_state=None)
    rf.fit(X_train, y_train)

    feature_importances = [(features.columns.values[i], rf.feature_importances_[i]) for i in range(len(rf.feature_importances_))]
    feature_importances = sorted(feature_importances, key=lambda x: x[1], reverse=True)
    print("Feature Importances: ", feature_importances)
    # evaluate accuract of random forest

    y_pred = rf.predict(X_test)

    ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, normalize='pred')

    plt.title(f'Confusion matrix for {ticker}')
    plt.show()
    print(classification_report(y_test, y_pred))

print(totalData.head())
features, labels = totalData.drop(['policy', 'Date'], axis=1), totalData['policy']
    
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)

# build and fit a random forest classifier on X_train and y_train
rf = RandomForestClassifier(n_estimators=100, random_state=None)
rf.fit(X_train, y_train)
# evaluate accuract of random forest

y_pred = rf.predict(X_test)

ConfusionMatrixDisplay.from_estimator(rf, X_test, y_test, normalize='pred')

plt.title(f'Confusion matrix for totalData')
plt.savefig('totalData_confusion_matrix.png')
plt.show()
print(classification_report(y_test, y_pred))
# Out:
# Feature Importances:  [('SAR', 0.16495715460074595), ('ROC_100', 0.09390143120943634), ('NATR', 0.093596209792849), ('SMA_100', 0.09199963738669982), ('APO', 0.06963048049745374), ('Chaikin', 0.06386877214059707), ('ROC_20', 0.05893247214528735), ('SMA_20', 0.05557524022808138), ('RSI', 0.05459795151294404), ('BandRadius', 0.053222016511490625), ('ROC_5', 0.052370156802862874), ('Ultimate', 0.05121311652734313), ('Williams%R', 0.04943534541809719), ('SMA_5', 0.0467000152261116)]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.93      0.86       211
#          1.0       0.70      0.41      0.52        46
#          2.0       0.73      0.68      0.70       113
#          3.0       0.71      0.64      0.67       105
#
#     accuracy                           0.76       475
#    macro avg       0.73      0.67      0.69       475
# weighted avg       0.75      0.76      0.75       475
#
# Feature Importances:  [('SAR', 0.1488089627540596), ('NATR', 0.09532340959145923), ('ROC_100', 0.09286582334169953), ('SMA_100', 0.09157543144025201), ('Chaikin', 0.07336842118797225), ('APO', 0.07052737474641733), ('SMA_20', 0.06282609096750189), ('RSI', 0.06107602634528566), ('ROC_20', 0.059057389400522596), ('BandRadius', 0.052079191475376374), ('Ultimate', 0.051213136920382096), ('Williams%R', 0.04857010298419672), ('ROC_5', 0.04666774386258221), ('SMA_5', 0.04604089498229241)]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.93      0.87       182
#          1.0       0.81      0.62      0.70        81
#          2.0       0.73      0.60      0.65        89
#          3.0       0.69      0.76      0.72       123
#
#     accuracy                           0.77       475
#    macro avg       0.76      0.72      0.74       475
# weighted avg       0.77      0.77      0.76       475
#
# Feature Importances:  [('SAR', 0.16136772658671877), ('NATR', 0.09550792686497227), ('SMA_100', 0.0927131742513934), ('ROC_100', 0.09156493882887715), ('APO', 0.07520474337643247), ('Chaikin', 0.06616517528101301), ('SMA_20', 0.060365147457705166), ('RSI', 0.059509960470489724), ('ROC_20', 0.05747059293990581), ('BandRadius', 0.05126914699168786), ('Ultimate', 0.05123425103078186), ('Williams%R', 0.04755078803545647), ('ROC_5', 0.04554135554577545), ('SMA_5', 0.044535072338790636)]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88       137
#          1.0       0.89      0.83      0.86        69
#          2.0       0.62      0.64      0.63        66
#          3.0       0.64      0.56      0.60        61
#
#     accuracy                           0.78       333
#    macro avg       0.75      0.73      0.74       333
# weighted avg       0.77      0.78      0.77       333
#
# Feature Importances:  [('NATR', 0.13227034977387522), ('SAR', 0.13048704267057665), ('ROC_100', 0.10554477341537993), ('Chaikin', 0.09115076000654888), ('SMA_100', 0.08062853053380811), ('APO', 0.06591983932135623), ('Williams%R', 0.06513397529506226), ('RSI', 0.053807957322042015), ('ROC_20', 0.05142104169235589), ('Ultimate', 0.05070812128574322), ('SMA_20', 0.049876072740223515), ('BandRadius', 0.04359143969748755), ('ROC_5', 0.04020808855607347), ('SMA_5', 0.03925200768946712)]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.72      0.77       122
#          1.0       0.86      0.87      0.86        68
#          2.0       0.78      0.88      0.82       187
#          3.0       0.79      0.71      0.75        98
#
#     accuracy                           0.80       475
#    macro avg       0.81      0.80      0.80       475
# weighted avg       0.80      0.80      0.80       475
#
# Feature Importances:  [('SAR', 0.12402367786272869), ('NATR', 0.12075371771866523), ('ROC_100', 0.09416883828156018), ('SMA_100', 0.08646814212055347), ('Chaikin', 0.07657787863501879), ('APO', 0.06858334255859061), ('Williams%R', 0.06110025360509559), ('Ultimate', 0.06024830325261206), ('SMA_20', 0.058300419770567706), ('ROC_20', 0.05576343691398333), ('RSI', 0.05528300254299593), ('BandRadius', 0.05220289337796729), ('ROC_5', 0.04346010224318427), ('SMA_5', 0.04306599111647671)]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83       129
#          1.0       0.84      0.85      0.84       132
#          2.0       0.76      0.76      0.76       136
#          3.0       0.63      0.62      0.62        78
#
#     accuracy                           0.78       475
#    macro avg       0.76      0.76      0.76       475
# weighted avg       0.78      0.78      0.78       475
#
# Feature Importances:  [('SAR', 0.1264833927646442), ('NATR', 0.1150172625887466), ('ROC_100', 0.10390347952445766), ('Chaikin', 0.08641035153484553), ('SMA_100', 0.0850750660391442), ('APO', 0.07285760098916302), ('Williams%R', 0.06389456099930906), ('ROC_20', 0.06138194387451304), ('RSI', 0.058247243802859915), ('SMA_20', 0.052378771595810704), ('Ultimate', 0.048553164754368446), ('BandRadius', 0.04558364581454019), ('SMA_5', 0.041247956695357045), ('ROC_5', 0.03896555902224031)]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.90      0.88       163
#          1.0       0.86      0.83      0.85        77
#          2.0       0.76      0.80      0.78       137
#          3.0       0.80      0.70      0.75        98
#
#     accuracy                           0.82       475
#    macro avg       0.82      0.81      0.82       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [('NATR', 0.1383575518600072), ('SAR', 0.1298093077019841), ('Chaikin', 0.10117187937181236), ('ROC_100', 0.09453217243825524), ('Williams%R', 0.0796162880720281), ('SMA_100', 0.07682021756017114), ('APO', 0.05801203679733679), ('ROC_20', 0.05469569955187161), ('SMA_20', 0.050860516725510264), ('Ultimate', 0.05006635936011224), ('RSI', 0.049470824397669484), ('BandRadius', 0.04111129309676656), ('ROC_5', 0.03829978493274967), ('SMA_5', 0.03717606813372525)]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83       129
#          1.0       0.80      0.90      0.85       105
#          2.0       0.71      0.82      0.76       110
#          3.0       0.84      0.65      0.73       131
#
#     accuracy                           0.79       475
#    macro avg       0.80      0.80      0.79       475
# weighted avg       0.80      0.79      0.79       475
#
# Feature Importances:  [('SAR', 0.12093813673431451), ('ROC_100', 0.11700976476226434), ('NATR', 0.11461599023894481), ('Chaikin', 0.10509122422005479), ('SMA_100', 0.08045193340874027), ('APO', 0.07064345605303259), ('Williams%R', 0.06179439722433042), ('ROC_20', 0.05665180769607997), ('Ultimate', 0.05383077220628175), ('RSI', 0.05063354357426043), ('SMA_20', 0.04639519041614974), ('BandRadius', 0.044635604712822775), ('ROC_5', 0.039182304863047926), ('SMA_5', 0.03812587388967568)]
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.84      0.83       136
#          1.0       0.80      0.80      0.80        81
#          2.0       0.79      0.84      0.81       177
#          3.0       0.71      0.59      0.64        81
#
#     accuracy                           0.79       475
#    macro avg       0.78      0.77      0.77       475
# weighted avg       0.79      0.79      0.79       475
#
# Feature Importances:  [('SAR', 0.1536073703395195), ('NATR', 0.150370499567841), ('Chaikin', 0.09439401455483391), ('SMA_100', 0.08762512995654402), ('ROC_100', 0.08419119070167855), ('Williams%R', 0.06361233116924231), ('APO', 0.05762820863322357), ('RSI', 0.05168949416409241), ('Ultimate', 0.05006788625373459), ('SMA_20', 0.04860385689644164), ('ROC_20', 0.04759314302260747), ('BandRadius', 0.03864777317237221), ('ROC_5', 0.03701921582620224), ('SMA_5', 0.03494988574166667)]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.78      0.82       124
#          1.0       0.90      0.85      0.88       117
#          2.0       0.77      0.85      0.81       154
#          3.0       0.77      0.76      0.77        80
#
#     accuracy                           0.82       475
#    macro avg       0.82      0.81      0.82       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [('SAR', 0.16808621920212807), ('NATR', 0.09837080366710167), ('SMA_100', 0.09619131203116318), ('ROC_100', 0.09057534765288369), ('APO', 0.07467597743650822), ('Chaikin', 0.06414557502651734), ('ROC_20', 0.05989686573687622), ('RSI', 0.055046105913223814), ('SMA_20', 0.054563646257158455), ('Ultimate', 0.05147924280247848), ('BandRadius', 0.04988162356257059), ('Williams%R', 0.04967669977752337), ('ROC_5', 0.04510206777508416), ('SMA_5', 0.04230851315878259)]
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.93      0.85       109
#          1.0       0.85      0.85      0.85        61
#          2.0       0.76      0.65      0.70        95
#          3.0       0.79      0.74      0.77        84
#
#     accuracy                           0.79       349
#    macro avg       0.80      0.79      0.79       349
# weighted avg       0.79      0.79      0.79       349
#
# Feature Importances:  [('SAR', 0.15115080064369907), ('ROC_100', 0.1255875789574608), ('SMA_100', 0.10885752464750018), ('NATR', 0.07326120158368789), ('APO', 0.0721755781631239), ('Chaikin', 0.07108276309699202), ('ROC_20', 0.06870725042312252), ('RSI', 0.05735957415982567), ('Ultimate', 0.05527504640525575), ('BandRadius', 0.0475857120425926), ('SMA_20', 0.0454401806503678), ('ROC_5', 0.04291305812630525), ('SMA_5', 0.04169855128558971), ('Williams%R', 0.03890517981447697)]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.91      0.87        54
#          1.0       0.76      0.59      0.67        32
#          2.0       0.56      0.53      0.54        19
#          3.0       0.59      0.65      0.62        34
#
#     accuracy                           0.72       139
#    macro avg       0.69      0.67      0.67       139
# weighted avg       0.72      0.72      0.72       139
#
# Feature Importances:  [('SAR', 0.1436406990065609), ('NATR', 0.0951536881015402), ('ROC_100', 0.09083668858580328), ('SMA_100', 0.08280365160929083), ('APO', 0.07711852094447984), ('Chaikin', 0.06731228757940352), ('ROC_20', 0.0660054871845249), ('SMA_20', 0.06113342837674757), ('RSI', 0.05766112440198515), ('Ultimate', 0.05508611225734748), ('BandRadius', 0.05343810364927376), ('Williams%R', 0.05293642861457096), ('ROC_5', 0.049440550412437195), ('SMA_5', 0.04743322927603441)]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.80      0.78       143
#          1.0       0.84      0.73      0.78        78
#          2.0       0.68      0.73      0.70       139
#          3.0       0.74      0.70      0.72       115
#
#     accuracy                           0.74       475
#    macro avg       0.76      0.74      0.75       475
# weighted avg       0.75      0.74      0.74       475
#
# Feature Importances:  [('SAR', 0.14834612625595778), ('NATR', 0.1297512356654425), ('Chaikin', 0.10602656107749946), ('ROC_100', 0.09751746899816854), ('SMA_100', 0.07636277965889157), ('Williams%R', 0.06997277321570633), ('APO', 0.05841696241190905), ('Ultimate', 0.05791263008004654), ('SMA_20', 0.04921559216113822), ('ROC_20', 0.04875240861191536), ('RSI', 0.046849062604212934), ('BandRadius', 0.04031362786298776), ('ROC_5', 0.03865061552808285), ('SMA_5', 0.03191215586804118)]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.76      0.83        79
#          1.0       0.85      0.92      0.88       135
#          2.0       0.81      0.88      0.84       164
#          3.0       0.81      0.72      0.77        97
#
#     accuracy                           0.84       475
#    macro avg       0.85      0.82      0.83       475
# weighted avg       0.84      0.84      0.84       475
#
# Feature Importances:  [('SAR', 0.13494058443195467), ('ROC_100', 0.09858113893206714), ('SMA_100', 0.09103718893348048), ('NATR', 0.0894557015983671), ('Chaikin', 0.08306550955330903), ('APO', 0.07210983226768707), ('Ultimate', 0.06541316988499575), ('ROC_20', 0.06261362889747046), ('RSI', 0.06018342749328494), ('SMA_20', 0.05478434666677921), ('BandRadius', 0.053871553312786334), ('Williams%R', 0.05048632121013671), ('ROC_5', 0.04365327828304948), ('SMA_5', 0.03980431853463157)]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89       205
#          1.0       0.86      0.89      0.88        91
#          2.0       0.72      0.73      0.72       103
#          3.0       0.83      0.57      0.67        76
#
#     accuracy                           0.82       475
#    macro avg       0.81      0.78      0.79       475
# weighted avg       0.82      0.82      0.82       475
#
# Feature Importances:  [('NATR', 0.14041915374722053), ('SAR', 0.13744263801074066), ('Chaikin', 0.1025998368842249), ('ROC_100', 0.08874126409933321), ('SMA_100', 0.07934790823918692), ('APO', 0.06316968917399812), ('Williams%R', 0.05828187490259545), ('Ultimate', 0.057330240384606955), ('ROC_20', 0.05449244768840431), ('RSI', 0.04959296913363079), ('SMA_20', 0.049414909049437725), ('BandRadius', 0.044324491832303047), ('ROC_5', 0.03806522525002669), ('SMA_5', 0.03677735160429076)]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.85      0.83       109
#          1.0       0.83      0.87      0.85        78
#          2.0       0.82      0.85      0.84       191
#          3.0       0.76      0.63      0.69        97
#
#     accuracy                           0.81       475
#    macro avg       0.80      0.80      0.80       475
# weighted avg       0.81      0.81      0.81       475
#
# Feature Importances:  [('SAR', 0.15999567822456912), ('SMA_100', 0.13286909893339602), ('NATR', 0.11786021710563627), ('ROC_100', 0.11099202020581239), ('Chaikin', 0.07328075884493714), ('APO', 0.061697184477534826), ('ROC_20', 0.05062985793903366), ('RSI', 0.04828790677782516), ('Williams%R', 0.0453754775603803), ('SMA_20', 0.04510999542454511), ('Ultimate', 0.04373288907372989), ('BandRadius', 0.0406722446523288), ('SMA_5', 0.03543311320402603), ('ROC_5', 0.03406355757624536)]
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.96      0.95        49
#          1.0       0.90      0.97      0.93        36
#          2.0       0.83      0.83      0.83        30
#          3.0       0.77      0.59      0.67        17
#
#     accuracy                           0.89       132
#    macro avg       0.86      0.84      0.85       132
# weighted avg       0.88      0.89      0.88       132
#
# Feature Importances:  [('SAR', 0.12350990355280383), ('NATR', 0.1208002042481366), ('ROC_100', 0.1125770959550906), ('Chaikin', 0.10638724682700146), ('SMA_100', 0.08277746845911718), ('Ultimate', 0.06595755389698935), ('Williams%R', 0.0617970020645302), ('APO', 0.06029733548231616), ('ROC_20', 0.05751269819078663), ('RSI', 0.05323748910928094), ('SMA_20', 0.05153768671802247), ('BandRadius', 0.03845299126513947), ('ROC_5', 0.034318302607043466), ('SMA_5', 0.030837021623741506)]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.72      0.78        90
#          1.0       0.82      0.99      0.90       133
#          2.0       0.82      0.86      0.84       120
#          3.0       0.91      0.77      0.84       132
#
#     accuracy                           0.85       475
#    macro avg       0.85      0.84      0.84       475
# weighted avg       0.85      0.85      0.84       475
#
# Feature Importances:  [('SAR', 0.16492588738448252), ('NATR', 0.10331174443518636), ('ROC_100', 0.098075994197757), ('SMA_100', 0.09041908366532925), ('APO', 0.06956064493340275), ('Chaikin', 0.06696229497901739), ('ROC_20', 0.06024085161012108), ('SMA_20', 0.05334160864417829), ('RSI', 0.0533240016694482), ('Ultimate', 0.0520632363753519), ('BandRadius', 0.0509468702624586), ('ROC_5', 0.04922717842021633), ('Williams%R', 0.04729696118450964), ('SMA_5', 0.040303642238540674)]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.97      0.92       184
#          1.0       0.90      0.84      0.87       102
#          2.0       0.82      0.70      0.75       109
#          3.0       0.72      0.72      0.72        80
#
#     accuracy                           0.84       475
#    macro avg       0.82      0.81      0.81       475
# weighted avg       0.84      0.84      0.84       475
#
# Feature Importances:  [('SAR', 0.12298309845814927), ('NATR', 0.11423899713713752), ('ROC_100', 0.08961822857053357), ('SMA_100', 0.08568073487079475), ('Chaikin', 0.07951769966280407), ('APO', 0.06908496712160113), ('RSI', 0.06421070044710088), ('ROC_20', 0.058799325094197365), ('SMA_20', 0.05834635485717382), ('Ultimate', 0.057082813204862456), ('BandRadius', 0.05446368100219314), ('Williams%R', 0.05297817512954509), ('ROC_5', 0.04762372021780875), ('SMA_5', 0.0453715042260981)]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.88      0.85       110
#          1.0       0.82      0.91      0.86       142
#          2.0       0.78      0.75      0.76       111
#          3.0       0.81      0.69      0.74       112
#
#     accuracy                           0.81       475
#    macro avg       0.81      0.81      0.81       475
# weighted avg       0.81      0.81      0.81       475
#
# Feature Importances:  [('SAR', 0.1426183584154842), ('ROC_100', 0.1092277723454047), ('NATR', 0.10184931224599991), ('SMA_100', 0.09464101040004001), ('APO', 0.07011781224414526), ('ROC_20', 0.06981793641705432), ('RSI', 0.06408214843365229), ('SMA_20', 0.06157414035749148), ('Chaikin', 0.06039583085815156), ('Ultimate', 0.05203586683886296), ('BandRadius', 0.04769609936080471), ('Williams%R', 0.0442048329153748), ('ROC_5', 0.04333189894390709), ('SMA_5', 0.03840698022362663)]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.93       201
#          1.0       0.86      0.87      0.86        99
#          2.0       0.74      0.77      0.76        87
#          3.0       0.79      0.74      0.76        88
#
#     accuracy                           0.85       475
#    macro avg       0.83      0.83      0.83       475
# weighted avg       0.85      0.85      0.85       475
#
#          Date        RSI   Ultimate  BandRadius       Chaikin      NATR  \
# 0  2012-04-17  46.489795  40.172901    0.017539 -2.317608e+06  2.760208
# 1  2012-04-18  50.201195  42.226659    0.020880 -2.024667e+06  2.716261
# 2  2012-04-19  50.242796  44.081433    0.021734 -2.277916e+06  2.701259
# 3  2012-04-20  48.610047  43.478910    0.022113 -3.105531e+06  2.661459
# 4  2012-04-23  46.103428  41.853508    0.013225 -2.531597e+06  2.663815
#
#       SMA_5    SMA_20   SMA_100       SAR  Williams%R       APO     ROC_5  \
# 0  0.999002  1.033505  0.989558  0.886300  -79.700196  0.000487  0.007541
# 1  0.988235  1.018679  0.975612  0.873868  -68.017200 -0.006056  0.016492
# 2  0.988509  1.018354  0.975569  0.873731  -67.887895 -0.010396  0.002150
# 3  0.995936  1.023721  0.981720  0.878882  -66.221985 -0.016266  0.008065
# 4  1.008054  1.031377  0.990480  0.887006  -75.506882 -0.019740  0.014771
#
#      ROC_20   ROC_100  policy
# 0  0.015470 -0.004544     0.0
# 1 -0.006551 -0.006603     0.0
# 2 -0.003286  0.011165     0.0
# 3 -0.012578  0.041557     0.0
# 4 -0.034865 -0.030440     0.0
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.87      0.81      2667
#          1.0       0.85      0.80      0.83      1707
#          2.0       0.76      0.74      0.75      2404
#          3.0       0.76      0.66      0.70      1765
#
#     accuracy                           0.78      8543
#    macro avg       0.78      0.77      0.77      8543
# weighted avg       0.78      0.78      0.78      8543

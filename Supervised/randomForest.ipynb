# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install sklearn
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (3.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (1.21.4)
# Requirement already satisfied: pandas in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\austi\anaconda3\envs\mlproj\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix

for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']
    
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, shuffle=True)
    
    # build and fit a random forest classifier on X_train and y_train
    rf = RandomForestClassifier(n_estimators=100, random_state=None)
    rf.fit(X_train, y_train)
    # evaluate accuract of random forest

    y_pred = rf.predict(X_test)
    plot_confusion_matrix(rf, X_test, y_test, normalize='pred')
    plt.title(f'Confusion matrix for {ticker}')
    plt.show()
    print(classification_report(y_test, y_pred))

    '''
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    # this confusion matrix sucks, even on own training data
    
    plot_confusion_matrix(model, X_test, y_test)
    
    plt.show()
    
    print(classification_report(y_test, y_pred, zero_division=0))
    '''
# Out:
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.92      0.85       207
#          1.0       0.89      0.46      0.61        54
#          2.0       0.75      0.66      0.70       117
#          3.0       0.74      0.80      0.77        97
#
#     accuracy                           0.78       475
#    macro avg       0.79      0.71      0.73       475
# weighted avg       0.78      0.78      0.77       475
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88       181
#          1.0       0.69      0.74      0.72        73
#          2.0       0.82      0.58      0.68       102
#          3.0       0.67      0.75      0.71       119
#
#     accuracy                           0.77       475
#    macro avg       0.76      0.74      0.75       475
# weighted avg       0.78      0.77      0.77       475
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.91      0.88       119
#          1.0       0.86      0.86      0.86        79
#          2.0       0.73      0.71      0.72        65
#          3.0       0.77      0.70      0.74        71
#
#     accuracy                           0.81       334
#    macro avg       0.80      0.80      0.80       334
# weighted avg       0.81      0.81      0.81       334
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.76      0.78       103
#          1.0       0.86      0.93      0.89        73
#          2.0       0.84      0.90      0.87       200
#          3.0       0.87      0.75      0.80        99
#
#     accuracy                           0.84       475
#    macro avg       0.85      0.83      0.84       475
# weighted avg       0.84      0.84      0.84       475
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.82      0.84       153
#          1.0       0.79      0.82      0.81        99
#          2.0       0.70      0.77      0.74       133
#          3.0       0.71      0.62      0.66        90
#
#     accuracy                           0.77       475
#    macro avg       0.77      0.76      0.76       475
# weighted avg       0.77      0.77      0.77       475
# C:\Users\austi\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.85      0.86       158
#          1.0       0.87      0.85      0.86        88
#          2.0       0.72      0.79      0.75       139
#          3.0       0.75      0.69      0.72        90
#
#     accuracy                           0.80       475
#    macro avg       0.80      0.80      0.80       475
# weighted avg       0.80      0.80      0.80       475
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22844/4068395481.py in <module>
#      12     # build and fit a random forest classifier on X_train and y_train
#      13     rf = RandomForestClassifier(n_estimators=100, random_state=None)
# ---> 14     rf.fit(X_train, y_train)
#      15     # evaluate accuract of random forest
#      16
#
# ~\anaconda3\envs\MLproj\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     440             # parallel_backend contexts set at a higher level,
#     441             # since correctness does not rely on using threads.
# --> 442             trees = Parallel(
#     443                 n_jobs=self.n_jobs,
#     444                 verbose=self.verbose,
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\MLproj\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\MLproj\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     209     def __call__(self, *args, **kwargs):
#     210         with config_context(**self.config):
# --> 211             return self.function(*args, **kwargs)
#     212
#     213
#
# ~\anaconda3\envs\MLproj\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\envs\MLproj\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\envs\MLproj\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

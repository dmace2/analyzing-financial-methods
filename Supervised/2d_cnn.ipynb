# %%
tickers = ["AMZN", "TSLA", "BABA", "HD", "TM", "NKE", "MCD", "LOW", "SBUX", "JD", "PDD", "BKNG", "GM", "MELI", "TJX", "NIO", "F", "LULU", "HMC", "CMG"]

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from scipy import stats

IMG_SIZE = 20

for ticker in tickers:
    data = pd.read_csv(f'./data_with_labels/{ticker}_with_labels.csv')
    features, labels = data.drop(['policy', 'Date'], axis=1), data['policy']

    if (ticker == "AMZN"):
        X = features.to_numpy()
        y = labels.to_numpy()
    else:
        X_new = features.to_numpy()
        y_new = labels.to_numpy()
        X = np.concatenate((X, X_new), axis=0)
        y = np.concatenate((y, y_new), axis=0)

# center each feature with 0 mean and unit variance
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# reshape the data into 2D images 
num_timestamps = X.shape[0]
img_size = IMG_SIZE
num_imgs = num_timestamps // img_size
X = X[: num_imgs * img_size, :]
y = y[: num_imgs * img_size]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(int(.2 * num_imgs)/num_imgs), shuffle=True)

X_train = np.reshape(X_train, (-1, img_size, 14, 1))
X_test = np.reshape(X_test, (-1, img_size, 14, 1))

# y_train_cat = np.round(np.median(np.reshape(y_train, (-1, img_size)), axis=1)).astype(int)
# y_test_cat = np.round(np.median(np.reshape(y_test, (-1, img_size)), axis=1)).astype(int)
y_train_cat = np.reshape(y_train, (-1, img_size))[:, -1]
y_test_cat = np.reshape(y_test, (-1, img_size))[:, -1]

enc = OneHotEncoder(handle_unknown='ignore')
y_train = enc.fit_transform(y_train_cat[:, np.newaxis]).toarray()
y_test_enc = enc.fit_transform(y_test_cat[:, np.newaxis]).toarray()

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test_enc.shape)

print("\nTrain labels:")
print(y_train_cat)
print("Test labels:")
print(y_test_cat)
print("\n")

h = plt.hist(y_train_cat)
txt = plt.title("Distribution of Class Labels in Training Data")
xlb = plt.xlabel("Trading Policy Label")
ylb = plt.ylabel("Frequency")
# Out:
# (1708, 20, 14, 1)
# (427, 20, 14, 1)
# (1708, 4)
# (427, 4)
#
# Train labels:
# [2. 3. 2. ... 3. 2. 1.]
# Test labels:
# [3. 0. 1. 1. 2. 2. 0. 2. 1. 0. 1. 2. 2. 2. 0. 1. 3. 3. 1. 1. 0. 2. 2. 1.
#  1. 2. 0. 0. 1. 3. 3. 2. 3. 2. 3. 0. 1. 3. 0. 2. 2. 3. 2. 0. 2. 0. 2. 3.
#  0. 0. 3. 0. 2. 2. 0. 1. 0. 0. 0. 1. 3. 1. 3. 3. 3. 2. 2. 1. 0. 0. 1. 1.
#  1. 0. 0. 2. 3. 2. 0. 1. 1. 3. 3. 0. 0. 1. 3. 0. 0. 2. 1. 0. 1. 1. 2. 3.
#  0. 3. 2. 3. 2. 0. 1. 2. 0. 1. 1. 2. 1. 0. 1. 3. 2. 0. 1. 1. 0. 1. 2. 1.
#  2. 0. 0. 2. 0. 0. 0. 2. 3. 1. 1. 1. 0. 2. 0. 1. 0. 2. 3. 0. 0. 0. 3. 0.
#  2. 0. 2. 1. 2. 2. 0. 2. 2. 2. 2. 1. 3. 1. 1. 1. 0. 1. 2. 0. 1. 3. 0. 2.
#  1. 2. 1. 0. 3. 2. 2. 0. 3. 0. 1. 0. 0. 0. 0. 2. 3. 2. 0. 2. 0. 1. 2. 0.
#  0. 2. 2. 1. 3. 1. 3. 3. 0. 2. 0. 0. 0. 3. 1. 0. 1. 3. 0. 2. 0. 2. 2. 2.
#  1. 1. 0. 3. 0. 1. 0. 2. 1. 0. 3. 3. 3. 2. 1. 1. 0. 3. 0. 0. 2. 0. 1. 0.
#  0. 2. 2. 0. 3. 3. 2. 3. 1. 2. 0. 2. 0. 0. 0. 2. 1. 0. 1. 3. 2. 0. 2. 2.
#  0. 3. 3. 0. 2. 2. 2. 0. 1. 0. 3. 1. 1. 0. 2. 2. 3. 1. 2. 0. 1. 1. 0. 1.
#  1. 0. 1. 3. 1. 0. 2. 2. 1. 0. 0. 0. 0. 1. 3. 2. 0. 3. 2. 1. 3. 3. 2. 2.
#  3. 0. 0. 1. 2. 3. 3. 0. 2. 1. 0. 1. 3. 1. 2. 0. 2. 1. 0. 2. 2. 1. 2. 2.
#  3. 2. 2. 2. 2. 2. 0. 1. 3. 2. 1. 1. 2. 3. 2. 3. 1. 0. 0. 3. 2. 0. 3. 2.
#  0. 2. 2. 0. 1. 1. 1. 0. 2. 1. 0. 1. 1. 2. 0. 2. 3. 2. 1. 0. 3. 1. 2. 0.
#  3. 0. 3. 2. 3. 2. 0. 0. 2. 2. 0. 0. 0. 0. 1. 2. 0. 1. 2. 0. 0. 1. 1. 1.
#  3. 2. 3. 1. 2. 0. 1. 2. 1. 0. 1. 3. 0. 3. 3. 3. 2. 0. 2.]

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

def create_model():
    model = models.Sequential()
    model.add(layers.Conv1D(16, 4, activation='relu', input_shape=(img_size, 14)))
    model.add(layers.MaxPooling1D((3,)))
    model.add(layers.Conv1D(32, 4, activation='relu'))
#     model.add(layers.MaxPooling2D((2, 2)))
#     model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(8, activation='relu'))
    model.add(layers.Dense(4))
    return model

# %%
model = create_model()
model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=100, 
                    validation_data=(X_test, y_test_enc))
# Out:
# W1202 15:47:30.358268 4755648000 ag_logging.py:146] AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x173474e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_20 (Conv1D)          (None, 17, 16)            912
#
#  max_pooling1d_14 (MaxPoolin  (None, 5, 16)            0
#  g1D)
#
#  conv1d_21 (Conv1D)          (None, 2, 32)             2080
#
#  flatten_6 (Flatten)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  dense_16 (Dense)            (None, 8)                 264
#
#  dense_17 (Dense)            (None, 4)                 36
#
# =================================================================
# Total params: 5,372
# Trainable params: 5,372
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x173474e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 33/54 [=================>............] - ETA: 0s - loss: 1.3899 - accuracy: 0.2869
# W1202 15:47:31.008016 4755648000 ag_logging.py:146] AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1735b84d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1735b84d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 54/54 [==============================] - 1s 10ms/step - loss: 1.3873 - accuracy: 0.2957 - val_loss: 1.3763 - val_accuracy: 0.3068
# Epoch 2/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.3682 - accuracy: 0.3144 - val_loss: 1.3691 - val_accuracy: 0.3068
# Epoch 3/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.3611 - accuracy: 0.3156 - val_loss: 1.3716 - val_accuracy: 0.3068
# Epoch 4/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.3480 - accuracy: 0.3238 - val_loss: 1.3794 - val_accuracy: 0.3021
# Epoch 5/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.3353 - accuracy: 0.3285 - val_loss: 1.3793 - val_accuracy: 0.2998
# Epoch 6/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.3231 - accuracy: 0.3413 - val_loss: 1.3856 - val_accuracy: 0.2904
# Epoch 7/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.3116 - accuracy: 0.3513 - val_loss: 1.3968 - val_accuracy: 0.2881
# Epoch 8/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.2962 - accuracy: 0.3624 - val_loss: 1.3980 - val_accuracy: 0.2693
# Epoch 9/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.2850 - accuracy: 0.3864 - val_loss: 1.4151 - val_accuracy: 0.2904
# Epoch 10/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.2668 - accuracy: 0.3923 - val_loss: 1.4220 - val_accuracy: 0.2834
# Epoch 11/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.2568 - accuracy: 0.4069 - val_loss: 1.4104 - val_accuracy: 0.2576
# Epoch 12/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.2384 - accuracy: 0.4210 - val_loss: 1.4513 - val_accuracy: 0.2787
# Epoch 13/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.2169 - accuracy: 0.4362 - val_loss: 1.4675 - val_accuracy: 0.2646
# Epoch 14/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.1980 - accuracy: 0.4385 - val_loss: 1.4637 - val_accuracy: 0.2693
# Epoch 15/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.1840 - accuracy: 0.4578 - val_loss: 1.5082 - val_accuracy: 0.2857
# Epoch 16/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.1598 - accuracy: 0.4719 - val_loss: 1.4951 - val_accuracy: 0.2763
# Epoch 17/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.1425 - accuracy: 0.4795 - val_loss: 1.5096 - val_accuracy: 0.2717
# Epoch 18/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.1239 - accuracy: 0.4883 - val_loss: 1.5573 - val_accuracy: 0.2553
# Epoch 19/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.0983 - accuracy: 0.5135 - val_loss: 1.5739 - val_accuracy: 0.2693
# Epoch 20/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.0714 - accuracy: 0.5146 - val_loss: 1.5973 - val_accuracy: 0.2974
# Epoch 21/100
# 54/54 [==============================] - 0s 3ms/step - loss: 1.0502 - accuracy: 0.5334 - val_loss: 1.6750 - val_accuracy: 0.2974
# Epoch 22/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.0341 - accuracy: 0.5410 - val_loss: 1.7525 - val_accuracy: 0.2646
# Epoch 23/100
# 54/54 [==============================] - 0s 2ms/step - loss: 1.0003 - accuracy: 0.5585 - val_loss: 1.8309 - val_accuracy: 0.2763
# Epoch 24/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.9816 - accuracy: 0.5697 - val_loss: 1.8415 - val_accuracy: 0.2763
# Epoch 25/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.9527 - accuracy: 0.5861 - val_loss: 1.8535 - val_accuracy: 0.2717
# Epoch 26/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.9296 - accuracy: 0.5978 - val_loss: 1.8569 - val_accuracy: 0.2670
# Epoch 27/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.9195 - accuracy: 0.6118 - val_loss: 1.9865 - val_accuracy: 0.2881
# Epoch 28/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.8790 - accuracy: 0.6364 - val_loss: 2.0066 - val_accuracy: 0.2717
# Epoch 29/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.8686 - accuracy: 0.6382 - val_loss: 2.0057 - val_accuracy: 0.2810
# Epoch 30/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.8301 - accuracy: 0.6511 - val_loss: 2.1487 - val_accuracy: 0.2717
# Epoch 31/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.8073 - accuracy: 0.6686 - val_loss: 2.0472 - val_accuracy: 0.2904
# Epoch 32/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7746 - accuracy: 0.6932 - val_loss: 2.1849 - val_accuracy: 0.2951
# Epoch 33/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7569 - accuracy: 0.6979 - val_loss: 2.2544 - val_accuracy: 0.2881
# Epoch 34/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7287 - accuracy: 0.7032 - val_loss: 2.3586 - val_accuracy: 0.2693
# Epoch 35/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7121 - accuracy: 0.7102 - val_loss: 2.3258 - val_accuracy: 0.2810
# Epoch 36/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.7096 - accuracy: 0.7213 - val_loss: 2.4266 - val_accuracy: 0.2881
# Epoch 37/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.7324 - val_loss: 2.4706 - val_accuracy: 0.2927
# Epoch 38/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6712 - accuracy: 0.7365 - val_loss: 2.5690 - val_accuracy: 0.2787
# Epoch 39/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6521 - accuracy: 0.7406 - val_loss: 2.6043 - val_accuracy: 0.2810
# Epoch 40/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6285 - accuracy: 0.7471 - val_loss: 2.5995 - val_accuracy: 0.2834
# Epoch 41/100
# 54/54 [==============================] - 0s 4ms/step - loss: 0.6047 - accuracy: 0.7641 - val_loss: 2.7149 - val_accuracy: 0.2810
# Epoch 42/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5795 - accuracy: 0.7758 - val_loss: 2.7925 - val_accuracy: 0.3044
# Epoch 43/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5559 - accuracy: 0.7869 - val_loss: 2.8185 - val_accuracy: 0.2763
# Epoch 44/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5514 - accuracy: 0.7834 - val_loss: 3.2093 - val_accuracy: 0.2740
# Epoch 45/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5496 - accuracy: 0.7910 - val_loss: 2.8624 - val_accuracy: 0.2810
# Epoch 46/100
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5246 - accuracy: 0.7980 - val_loss: 3.2944 - val_accuracy: 0.2881
# Epoch 47/100
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5101 - accuracy: 0.7998 - val_loss: 3.0739 - val_accuracy: 0.2810
# Epoch 48/100
#  1/54 [..............................] - ETA: 0s - loss: 0.4362 - accuracy: 0.9062

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0,1.05])
plt.legend(loc='lower right')
plt.savefig('./cnn_figs/overfit_model_training.png')

test_loss, test_acc = model.evaluate(X_test, y_test_enc, verbose=2)
# Out:
# 14/14 - 0s - loss: 6.5573 - accuracy: 0.2436 - 30ms/epoch - 2ms/step

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)



#     thresh = cm.numpy().max() / 1.5 if normalize else cm.numpy().max() / 2
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig('./cnn_figs/overfit_confusion.png')
    plt.show()

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

print(y_pred.shape)
print(y_test_cat.shape)
cm = confusion_matrix(y_test_cat, y_pred)
plot_confusion_matrix(cm, np.arange(4))
# Out:
# (426,)
# (426,)
